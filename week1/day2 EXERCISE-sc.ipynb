# %% [markdown]
# # Welcome to your first assignment!
#
# Instructions are below. Please give this a try, and look in the solutions folder if you get stuck (or feel free to ask me!)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get to the assignment --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code below from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Let's just make sure the model is loaded

# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Creation**: Generative AI can generate high-quality content such as images, videos, and text based on a given prompt or style. This can be used for content marketing, social media management, and advertising.
# 2. **Product Design and Development**: Generative AI can help designers create new product concepts, prototypes, and designs by generating 3D models, textures, and materials.
# 3. **Virtual Assistants and Chatbots**: Generative AI can power virtual assistants like Siri, Alexa, or Google Assistant by generating responses to user queries and providing personalized recommendations.
# 4. **Marketing Automation**: Generative AI can help automate marketing processes such as email marketing, social media management, and customer service by generating personalized messages and responses.
# 5. **Predictive Maintenance**: Generative AI can analyze sensor data from equipment and predict when maintenance is required, reducing downtime and increasing efficiency.
# 6. **Personalized Recommendations**: Generative AI can generate personalized product recommendations for e-commerce websites, streaming services, and online retailers.
# 7. **Data Analysis and Visualization**: Generative AI can help analyze and visualize large datasets by generating insights, trends, and patterns.
# 8. **Cybersecurity**: Generative AI can be used to detect and respond to cyber threats by analyzing network traffic, identifying anomalies, and generating incident response plans.
# 9. **Customer Service**: Generative AI can power chatbots that provide 24/7 customer support, answering common questions and routing complex issues to human representatives.
# 10. **Supply Chain Optimization**: Generative AI can help optimize supply chain operations by predicting demand, managing inventory, and identifying potential bottlenecks.
#
# Some specific business applications of Generative AI include:
#
# * **Autonomous vehicles**: Generative AI is used to generate terrain maps, detect obstacles, and predict pedestrian behavior.
# * **Virtual event planning**: Generative AI can generate virtual event concepts, layouts, and decor based on a given theme or style.
# * **Product configurators**: Generative AI can help design and configure products such as furniture, electronics, and appliances.
# * **Medical diagnosis**: Generative AI can analyze medical images to detect diseases, predict patient outcomes, and provide personalized treatment plans.
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative uses across various industries.

# %% [markdown]
# # Introducing the ollama package
#
# And now we'll do the same thing, but using the elegant ollama python package instead of a direct HTTP call.
#
# Under the hood, it's making the same call as above to the ollama server running at localhost:11434

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Creation**: AI-powered tools can generate high-quality content such as blog posts, social media posts, product descriptions, and even entire articles.
# 2. **Marketing Automation**: Generative AI can create personalized marketing campaigns, advertisements, and sales scripts based on customer data and behavior.
# 3. **Product Design**: AI can generate 2D and 3D designs for products, packaging, and branding materials, reducing the need for human designers.
# 4. **Chatbots and Virtual Assistants**: Generative AI enables the creation of conversational interfaces that can understand and respond to user queries, providing a personalized experience.
# 5. **Data Visualization**: AI can generate interactive and dynamic visualizations of complex data sets, helping businesses make informed decisions.
# 6. **Customer Service**: Generative AI-powered chatbots and virtual assistants can provide 24/7 customer support, responding to common inquiries and freeing up human agents for more complex issues.
# 7. **Content Localization**: AI can translate content into multiple languages, making it accessible to global audiences and reducing the need for manual translation.
# 8. **Social Media Management**: Generative AI can create social media posts, respond to comments, and analyze engagement metrics, helping businesses optimize their social media presence.
# 9. **Influencer Marketing**: AI-powered tools can identify influencers based on niche audiences, track their performance, and even generate content suggestions.
# 10. **Product Recommendations**: Generative AI can suggest products based on customer behavior, preferences, and purchase history, improving the overall shopping experience.
# 11. **Content Optimization**: AI can analyze and optimize existing content to improve engagement, click-through rates, and conversion rates.
# 12. **Automated Transcription**: Generative AI-powered tools can transcribe audio and video files with high accuracy, reducing the need for manual transcription services.
# 13. **Brand Voice Consistency**: AI can analyze brand tone, language, and style across various channels to ensure consistency and authenticity.
# 14. **Content Editing**: Generative AI can edit and refine existing content to improve clarity, coherence, and overall quality.
# 15. **Virtual Event Planning**: AI-powered tools can plan and manage virtual events, including scheduling, logistics, and engagement activities.
#
# These applications are just a few examples of the many ways Generative AI is transforming businesses across various industries. As the technology continues to evolve, we can expect even more innovative use cases to emerge.

# %% [markdown]
# ## Alternative approach - using OpenAI python library to connect to Ollama

# %% [markdown]
# ## Also trying the amazing reasoning model DeepSeek
#
# Here we use the version of DeepSeek-reasoner that's been distilled to 1.5B.
# This is actually a 1.5B variant of Qwen that has been fine-tuned using synethic data generated by Deepseek R1.
#
# Other sizes of DeepSeek are [here](https://ollama.com/library/deepseek-r1) all the way up to the full 671B parameter version, which would use up 404GB of your drive and is far too large for most!

# %%
# !ollama pull deepseek-r1:1.5b
# Out:
# pulling manifest ⠙ pulling manifest ⠙ pulling manifest
# pulling aabd4debf0c8... 100% ▕████████████████▏ 1.1 GB
# pulling 369ca498f347... 100% ▕████████████████▏  387 B
# pulling 6e4c38e1172f... 100% ▕████████████████▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕████████████████▏  148 B
# pulling a85fe2a2e58e... 100% ▕████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success

# %%
# This may take a few minutes to run! You should then see a fascinating "thinking" trace inside <think> tags, followed by some decent definitions

response = ollama_via_openai.chat.completions.create(
    model="deepseek-r1:1.5b",
    messages=[{"role": "user", "content": "Please give definitions of some core concepts behind LLMs: a neural network, attention and the transformer"}]
)

print(response.choices[0].message.content)
# Out:
# <think>
# Okay, so I need to figure out the definitions for three core concepts related to large language models (LLMs):Neural networks, attention, and transformers. Hmm, where do I start? I'm pretty new to this, so I'll have to break it down step by step.
#
# First, neural networks. From what I remember in classes, a neural network is kinda like those complicated computer models that have lots of layers with neurons. Oh wait, each neuron has some weight and bias. The model processes inputs through these layers and outputs something based on all the connections between the nodes. So maybe it's like processing data through different levels of abstraction to predict something?
#
# But how does that connect specifically to LLMs? Oh right, because LLMs are a type of neural network, called "large" due to their size—so they probably have many layers and neurons, which makes them very powerful for generating text. Wait, but I'm not entirely sure about the details beyond just defining it as a neural network.
#
# Next up is attention. This seems important in LLMs because they process text with context-aware models. So attention must be how the model focuses on certain parts of the input text when making decisions. From reading, I think if something happens far away from where you're processing doesn't affect what you're looking at. Or was it like a sliding window that moves through the text and the attention mechanism captures relevant parts?
#
# And then there's transformers. These are probably different than standard neural networks because they use attention. Wait, no, wait—it might be similar but built differently. I'm pretty certain that the transformer architecture uses self-attention mechanisms where each position in the input is processed relative to itself. Maybe it's like breaking down the text into tokens and processing each one with its own context from the previous ones.
#
# Putting this together: Neural networks are these intricate connections of neurons modeling data. Attention allows models to focus on specific parts through time or context. Transformers, being a type of neural network with self-attention in their layers, help LLMs process text by focusing on relevant parts based on previous information.
#
# I think I got the basics covered but need to make sure my definitions are accurate. Maybe check if I can find sources that explain these concepts in more detailed terms to avoid confusion.
# </think>
#
# **Core Concepts Behind Large Language Models (LLMs):**
#
# 1. **Neural Networks:**
#    Neural networks are computational models inspired by the structure and function of biological neural systems. They consist of layers of interconnected nodes, or neurons, each with_weights and biases that adjust during training. These networks process input data through multiple layers, transforming it into abstract representations to make predictions or decisions.
#
# 2. **Attention:**
#    Attention is a mechanism in LLMs that allows models to focus on specific parts of the input text over time or context. It enables the model to concentrate on relevant and meaningful information while ignoring irrelevant details, ensuring they do not affect higher-level processing.
#
# 3. **Transformers:**
#    Transformers are neural network architectures with self-attention mechanisms integrated into their structure using layers of attention. This allows each token in a sequence to process its context based on the previous tokens, making LLMs highly effective at capturing Dependencies between sequences automatically.

# %% [markdown]
# # NOW the exercise for you
#
# Take the code from day1 and incorporate it here, to build a website summarizer that uses Llama 3.2 running locally instead of OpenAI; use either of the above approaches.

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from openai import OpenAI

# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

openai = OpenAI()
# Out:
# API key found and looks good so far!

# %%
# A class to represent a Webpage
# If you're not familiar with Classes, check out the "Intermediate Python" notebook

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# Let's try one out. Change the website and add print statements to follow along.

eps = Website("http://eperforms.com")
print(eps.title)
# print(eps.text)
# Out:
# Enterprise Performance Strategies
# ePerforms.com
# Welcome to
# Enterprise Performance Strategies
# Enterprise Performance Strategies is a newly formed company that provides end to end business
#                 solutions around enterprise compensation management (ECM),
#                 enterprise incentive management (EIM), and business performance
#                 enhancing software and services. The people who make up
#                 EPS are leaders in their fields, from technical experts in
#                 software development and implementation for EIM, ECM, business
#                 process management (BPM), and business rule engine (BRE)
#                 systems, to business strategy experts focusing on best practices
#                 in organization and compensation design and business process
#                 re-engineering.
# Improve your results with ePerforms
# With our tools
#                 and techniques, customers are seeing tangible improvements
#                 in their business performance:
# Employees at all levels of the enterprise focus more on the
#                 customers, products, and activities that best drive the
#                 business.
# Both top & bottom
#                 line results improve with better compensation and business practices.
# Employee and
#                 partner performance are enhanced with more real time
#                 feedback and information.
# Watch this Space!
# As we are a young
#                         company, we are working with partners and customers to
#                         develop and refine our software and services.  As
#                         our products become generally available, we will
#                         highlight them here.
# New!
# epsResolve
# ™
# available soon!
# Our first product will
# 						be generally available soon.  For more
# 						information, see our
# products
# 						page
# .
# Contact Us
# We are accepting
#                         expressions of interest from potential customers
#                         interested in joining our charter development customer
#                         program.  For more information, contact us at:
# Charter@ePerforms.com
# Copyright
# 		© 2005 Enterprise Performance Strategies, Inc. All rights reserved

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# A function that writes a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# print(user_prompt_for(eps))

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

messages_for(eps)
# Out:
# [{'role': 'system',
#   'content': 'You are an assistant that analyzes the contents of a website and provides a short summary, ignoring text that might be navigation related. Respond in markdown.'},
#  {'role': 'user',
#   'content': 'You are looking at a website titled Enterprise Performance Strategies\nThe contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.\n\nePerforms.com\nWelcome to\nEnterprise Performance Strategies\nEnterprise Performance Strategies is a newly formed company that provides end to end business \r\n                solutions around enterprise compensation management (ECM), \r\n                enterprise incentive management (EIM), and business performance \r\n                enhancing software and services. The people who make up \r\n                EPS are leaders in their fields, from technical experts in \r\n                software development and implementation for EIM, ECM, business \r\n                process management (BPM), and business rule engine (BRE) \r\n                systems, to business strategy experts focusing on best practices \r\n                in organization and compensation design and business process \r\n                re-engineering.\nImprove your results with ePerforms\nWith our tools \r\n                and techniques, customers are seeing tangible improvements \r\n                in their business performance:\nEmployees at all levels of the enterprise focus more on the \r\n                customers, products, and activities that best drive the \r\n                business.\nBoth top & bottom \r\n                line results improve with better compensation and business practices.\nEmployee and \r\n                partner performance are enhanced with more real time \r\n                feedback and information.\nWatch this Space!\nAs we are a young \r\n                        company, we are working with partners and customers to \r\n                        develop and refine our software and services.\xa0 As \r\n                        our products become generally available, we will \r\n                        highlight them here.\nNew!\nepsResolve\n™\navailable soon!\nOur first product will \r\n\t\t\t\t\t\tbe generally available soon.\xa0 For more \r\n\t\t\t\t\t\tinformation, see our\nproducts \r\n\t\t\t\t\t\tpage\n.\nContact Us\nWe are accepting \r\n                        expressions of interest from potential customers \r\n                        interested in joining our charter development customer \r\n                        program.\xa0 For more information, contact us at:\nCharter@ePerforms.com\nCopyright \r\n\t\t© 2005 Enterprise Performance Strategies, Inc. All rights reserved'}]

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    website = Website(url)
    # response = openai.chat.completions.create(
    #     model = "gpt-4o-mini",
    #     messages = messages_for(website)
    # )
    response = ollama_via_openai.chat.completions.create(
        model="deepseek-r1:1.5b",
        # messages=[{"role": "user", "content": "Please give definitions of some core concepts behind LLMs: a neural network, attention and the transformer"}]
        messages=messages_for(website)
    )
    return response.choices[0].message.content

# summarize("http://eperforms.com")

# A function to display this nicely in the Jupyter output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

display_summary("http://eperforms.com")
# Out:
# <think>
# Okay, I'm looking at this query where the user provided a website titled "Enterprise Performance Strategies" and asked for a short summary in markdown. They also mentioned that if there are news or announcements, to summarize those too.
#
# I start by understanding what each section says. The homepage introduces ePerforms as a new company providing software solutions around ECM, EIM, and compensation management. It talks about their team of experts from software development and implements for these areas and process management and business rule engines.
#
# Then it goes into Improve your results with ePerforms, mentioning employee focus on customer benefits, improvements in performance metrics, improved compensation practices, real-time feedback, and enhanced employee/partner performance with data.
#
# Next, the page explains as a young company working with partners to refine their software. It brings up new! epsResolve™ available soon; their first product is getting closer and they have a contact method.
#
# It also lists products on another section but isn't adding more in this query.
#
# The conclusion summarizes that ePerforms is seeking interest through their Charter Development program, focusing on ECN and EBM, offering solutions and services. They offer guidance for companies facing performance challenges or growth opportunities.
#
# Putting it all together, I need to structure the summary succinctly without going into too much detail but covering the introduction, key features, business approach, product news, and contact info.
# </think>
#
# ePerforms.com is a startup focused on providing enterprise compensation and incentive management solutions. The company teams their experts in enterprise performance planning with software tools that enable employees and partners to focus more on customer value creation.
#
# As a rapidly growing organization, ePerforms is advancing its products with real-time feedback loops that drive business improvement. With resources tailored to different stages of a company's growth, ePerforms helps organizations navigate challenges or capitalize on opportunities.
#
# For more information, you can visit their website at [ePerforms.com](http://www.ePerforms.com).
